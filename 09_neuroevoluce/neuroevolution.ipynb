# %% [markdown]
# # Neuroevoluce
#
# Pomocí evolučních algoritmů můžeme vyvíjet i celé neuronové sítě. Buď můžeme evolvovat váhy mezi neurony, strukturu sítě nebo obojí najednou. Nejprve se podíváme, jak naimplementovat jednoduchý algoritmus pro evoluci vah, následně si zkusíme i evoluci vah a struktury sítě najednou pomocí algoritmu NEAT.
#
# ## Evoluce vah
#
# Evoluce vah je jednoduchá, stačí naimplementovat jednoduchou neuronovou síť, které umíme nastavit parametry. Náš jedinec v evoluci bude jeden dlouhý vektor, který bude reprezentovat váhy mezi vrstvami v neuronové síti. Při vyhodnocování tedy nastavíme síti váhy podle daného jedince a spočítáme její výstup. Zkusíme si tímto způsobem implementovat klasifikaci na našem oblíbeném datasetu iris.

# %%
import numpy as np

from sklearn import datasets, model_selection

from deap import algorithms, creator, base, cma, tools

# %% [markdown]
# Začneme tím, že si připravíme jednoduchou implementaci neuronové sítě. Při inicializaci nastavíme vrstvy, jejich velikosti a také jejich aktivace, jelikož každá vrstva může mít svou vlastní aktivační funkci.
#
# Dále budeme potřebovat jednoho dlouhého linárního jedince všech vah rozdělit na váhové matice. To uděláme tak, že budeme brát vždy velikost akutální a následující vrstvy, na základě toho vezmeme odpovídající část jedince a vytvoříme z něj matici vah. Zároveň musíme přidat biasy, takže velikost aktuální vrstvy zvětšíme ještě o 1.
#
# Nakonec bude potřeba ještě funkce pro evaluaci sítě, která vytvořenou síť vyhodnotí tak, že pro každou vrstvu použije odpovídající aktivaci a vrátí nám výstup sítě.

# %%
class NeuralNetwork: 
    def __init__(self, layer_sizes, activations):
        self.layer_sizes = layer_sizes
        self.layers = None

        # Checking, whether the number of activations corresponds to the number of layers
        if len(list(activations)) != len(layer_sizes) - 1:
            raise AttributeError("Number of activations does not match number of layers")
        
        self.activations = list(activations)
        self.vectorized_net = None


    # Returns complete nuber of parameters of the network
    def vectorized_size(self):
        return sum(map(lambda x: (x[0] + 1) * x[1], zip(self.layer_sizes, self.layer_sizes[1:])))


    # Sets weights of the network using the values given by the linear individual
    def set_weights(self, vectorized_net):
        
        # Checking, whether the sizes match
        if len(vectorized_net) != self.vectorized_size():
            raise AttributeError(
                f"Length of vector does not match vectorized_size: {len(vectorized_net)} != {self.vectorized_size()}"
            )

        self.vectorized_net = vectorized_net
        self.layers = []
        sum_sizes = 0 # Sum of sizes of the previous layers (number of already processed elements)
        
        # Go through layers and set weight matrix between the current one and the following one
        # using the corresponding values from the linear indivudual.
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
            number_of_corresponding_elements = (input_layer_size + 1) * output_layer_size
            
            layer = vectorized_net[sum_sizes:(sum_sizes + number_of_corresponding_elements)]
            self.layers.append(np.reshape(layer, newshape=(input_layer_size + 1, output_layer_size))) # Reshaping to the correct format
            
            sum_sizes += number_of_corresponding_elements


    # Evaluation of the network
    def eval_network(self, inputs):
        activations = inputs
        
        for activation_function, layer in zip(self.activations, self.layers):
            activations_1 = np.append(np.array([1.0]), activations)  # Extending the input vector by a constant one to be multiplied by the bias part of the weights
            activations = activation_function(np.dot(activations_1, layer))

        return activations

# %% [markdown]
# Nyní si akorát načteme data a rozdělíme si je na trénovací a testovací.

# %%
iris = datasets.load_iris()
train_x, test_x, train_y, test_y = model_selection.train_test_split(iris.data, iris.target)

# %% [markdown]
# Musíme si ještě definovat fitness funkci, což bude pouze vyhodnocení sítě na datech, kdy vždy vybereme jako predikovanou třídu tu s maximální pravděpodobností a spočítáme pak celkovou accuracy. Zároveň si definujeme vlastní lineární a relu aktivace.

# %%
def relu(x):
    return np.maximum(0, x)

def linear(x):
    return x

def fitness(net, ind, X, y):
    net.set_weights(ind)
    
    acc = 0
    for xi, yi in zip(X, y):
        if np.argmax(net.eval_network(xi)) == yi:
            acc += 1
    
    return acc / len(y),

# %% [markdown]
# Pro samotné nastavení vah neuronové sítě použíjeme algoritmus CMA-ES, což je evoluční strategie, která je velmi dobrá na úlohy spojité optimalizace, kterou máme i zde. V evoluční strategii se většinou nevyskytuje křížení, ale místo něj se klade důraz na mutaci. Zde se používá námi známá gaussovská mutace. Evoluční strategii používáme také proto, že nám umožňuje váhy měnit korelovaně, protože si pamatuje celou kovariační matici, ze které generuje jedince. Klasická evoluce umí měnit váhy jen nezávisle na sobě, a dává proto horší výsledky. CMA-ES je implementována v knihovně deap, a je tedy snadné ji použít.

# %%
net = NeuralNetwork([4, 5, 3], [relu, linear])
ind_size = net.vectorized_size()    
    
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("evaluate", lambda ind, X, y: fitness(net, ind, X, y), X=train_x, y=train_y)

strategy = cma.Strategy(centroid=[0.0] * ind_size, sigma=0.1, lambda_= 5 * ind_size)
toolbox.register("generate", strategy.generate, creator.Individual)
toolbox.register("update", strategy.update)

hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

_ = algorithms.eaGenerateUpdate(toolbox, ngen=250, stats=stats, halloffame=hof)
# Out:
# gen	nevals	avg     	std      	min	max
# 0  	215   	0.330108	0.0828311	0  	0.651786
# 1  	215   	0.330606	0.0966786	0  	0.660714
# 2  	215   	0.342899	0.0996363	0  	0.651786
# 3  	215   	0.347384	0.0932352	0  	0.651786
# 4  	215   	0.357475	0.0989378	0  	0.660714
# 5  	215   	0.348048	0.0829342	0  	0.651786
# 6  	215   	0.366279	0.0906517	0  	0.660714
# 7  	215   	0.378073	0.114576 	0  	0.848214
# 8  	215   	0.38912 	0.114514 	0  	0.732143
# 9  	215   	0.387334	0.119319 	0.0535714	0.857143
# 10 	215   	0.395598	0.143463 	0        	0.919643
# 11 	215   	0.407766	0.129246 	0.267857 	0.660714
# 12 	215   	0.417027	0.143897 	0        	0.794643
# 13 	215   	0.431686	0.145695 	0.0535714	0.919643
# 14 	215   	0.459095	0.150312 	0.0803571	0.866071
# 15 	215   	0.458181	0.166699 	0.178571 	0.973214
# 16 	215   	0.449045	0.149441 	0        	0.723214
# 17 	215   	0.455233	0.150222 	0        	0.839286
# 18 	215   	0.457309	0.16397  	0        	0.910714
# 19 	215   	0.46848 	0.155955 	0        	0.9375
# 20 	215   	0.487126	0.156014 	0.0625   	0.955357
# 21 	215   	0.514327	0.159186 	0        	0.910714
# 22 	215   	0.500914	0.153088 	0        	0.776786
215   	0.982143	2.22045e-16	0.982143  	0.982143
# 230	215   	0.98206 	0.000857133	0.973214  	0.982143
# 231	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 232	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 233	215   	0.98206 	0.000857133	0.973214  	0.982143
# 234	215   	0.981977	0.00120647 	0.973214  	0.982143
# 235	215   	0.982101	0.000607506	0.973214  	0.982143
# 236	215   	0.982101	0.000607506	0.973214  	0.982143
# 237	215   	0.982101	0.000607506	0.973214  	0.982143
# 238	215   	0.982018	0.00135588 	0.964286  	0.982143
# 239	215   	0.981935	0.00159762 	0.964286  	0.982143
# 240	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 241	215   	0.982018	0.0010473  	0.973214  	0.982143
# 242	215   	0.98206 	0.000857133	0.973214  	0.982143
# 243	215   	0.982018	0.0010473  	0.973214  	0.982143
# 244	215   	0.981977	0.00120647 	0.973214  	0.982143
# 245	215   	0.982018	0.0010473  	0.973214  	0.982143
# 246	215   	0.981852	0.00158462 	0.973214  	0.982143
# 247	215   	0.981977	0.00120647 	0.973214  	0.982143
# 248	215   	0.981894	0.00147059 	0.973214  	0.982143
# 249	215   	0.981977	0.00120647 	0.973214  	0.982143

# %% [markdown]
# Na závěr si zkusíme otestovat síť na testovacích datech a změřit na nich accuracy.

# %%
accuracy = fitness(net, hof[0], test_x, test_y)[0]
print("Achieved accuracy:", accuracy)
# Out:
# Achieved accuracy: 1.0

# %% [markdown]
# ## NEAT
#
# Zkusíme se podívat na algoritmus NEAT na příkladu s datasetem iris a zkusíme pro něj najít co nejvhodnější síť, která bude umět data pokud možno co nejlépe klasifikovat. Samotná implementace algorimtu není vůbec jednoduchá, ale naštěstí v pythonu existuje knihovna neat-python, kde už tu práci někdo udělal za nás (instalujeme pomocí `pip install neat-python`). Knihovna má trochu jiný interface, než na co jsme zvyklí, ale není složité se jí naučit používat. Nastavení parametrů algoritmu se načítá ze zvláštního souboru *config-feedforward*. Dokumentace k jeho formátování se nachází [zde](https://neat-python.readthedocs.io/en/latest/config_file.html). Potom už stačí jen algoritmus spustit. Níže uvedený příklad vychází z dokumentace k [neat-python](https://github.com/CodeReclaimers/neat-python/tree/master/examples/xor) upravený pro naši klasifikaci irisů.

# %%
import neat
import visualize

# %%
# Construction and evaluation of a network in NEAT - basically a fitness function
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = 0.0
        net = neat.nn.FeedForwardNetwork.create(genome, config) 
        
        for xi, xo in zip(train_x, train_y): 
            output = net.activate(xi)
            if np.argmax(output) == xo:
                genome.fitness += 1

# %%
# Path to the configuration file
config_path = "config-feedforward"

# Load NEAT configuration
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)

# Create new population
population = neat.Population(config)

# Add statistics computation for evolution logging
population.add_reporter(neat.StdOutReporter(show_species_detail=True))
stats = neat.StatisticsReporter()
population.add_reporter(stats)

# Run for a given number of generations
winner = population.run(eval_genomes, 100)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 34.86667 stdev: 14.34325
# Best fitness: 72.00000 - size: (3, 12) - species 1 - id 96
# Average adjusted fitness: 0.484
# Mean genetic distance 1.296, standard deviation 0.271
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150     72.0    0.484     0
# Total extinctions: 0
# Generation time: 0.310 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 38.91333 stdev: 10.66704
# Best fitness: 72.00000 - size: (3, 12) - species 1 - id 96
# Average adjusted fitness: 0.499
# Mean genetic distance 1.273, standard deviation 0.295
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150     72.0    0.499     1
# Total extinctions: 0
# Generation time: 0.285 sec (0.297 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 41.90667 stdev: 13.87580
# Best fitness: 73.00000 - size: (3, 12) - species 1 - id 300
# Average adjusted fitness: 0.562
# Mean genetic distance 1.274, standard deviation 0.291
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150     73.0    0.562     0
# Total extinctions: 0
# Generation time: 0.279 sec (0.291 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 43.72000 stdev: 15.34715
# Best fitness: 85.00000 - size: (3, 12) - species 1 - id 478
# Average adjusted fitness: 0.509
# Mean genetic distance 1.322, standard deviation 0.284
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   150     85.0    0.509     0
# Total extinctions: 0
# Generation time: 0.254 sec (0.282 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 46.84667 stdev: 16.21347
# Best fitness: 85.00000 - size: (3, 12) - species 1 - id 478
# Average adjusted fitness: 0.375
# Mean genetic distance 1.428, standard deviation 0.297
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   150     85.0    0.375     1
# Total extinctions: 0
# Generation time: 0.266 sec (0.279 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 45.46667 stdev: 16.30242
# Best fitness: 85.00000 - size: (3, 12) - species 1 - id 478
# Average adjusted fitness: 0.480
# Mean genetic distance 1.561, standard deviation 0.300
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   150     85.0    0.480     2
# Total extinctions: 0
# Generation time: 0.267 sec (0.277 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 51.16000 stdev: 18.03777
# Best fitness: 85.00000 - size: (3, 12) - species 1 - id 478
# Average adjusted fitness: 0.592
# Mean genetic distance 1.662, standard deviation 0.289
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   150     85.0    0.592     3
# Total extinctions: 0
# Generation time: 0.270 sec (0.276 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 48.97333 stdev: 17.72680
# Best fitness: 85.00000 - size: (3, 8) - species 1 - id 929
# Average adjusted fitness: 0.576
# Mean genetic distance 1.623, standard deviation 0.327
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   150     85.0    0.576     4
# Total extinctions: 0
# Generation time: 0.285 sec (0.277 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 51.10667 stdev: 18.57064
# Best fitness: 101.00000 - size: (3, 8) - species 1 - id 1246
# Average adjusted fitness: 0.344
# Mean genetic distance 1.557, standard deviation 0.336
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   150    101.0    0.344     0
# Total extinctions: 0
# Generation time: 0.263 sec (0.275 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 53.38667 stdev: 19.10943
# Best fitness: 105.00000 - size: (3, 8) - species 1 - id 1365
# Average adjusted fitness: 0.484
# Mean genetic distance 1.755, standard deviation 0.352
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   150    105.0    0.484     0
# Total extinctions: 0
# Generation time: 0.254 sec (0.273 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 54.92000 stdev: 17.81929
# Best fitness: 105.00000 - size: (3, 8) - species 1 - id 1365
# Average adjusted fitness: 0.489
# Mean genetic distance 1.902, standard deviation 0.373
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   150    105.0    0.489     1
# Total extinctions: 0
# Generation time: 0.263 sec (0.269 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 55.50667 stdev: 17.88360
# Best fitness: 105.00000 - size: (3, 8) - species 1 - id 1365
# Average adjusted fitness: 0.322
# Mean genetic distance 1.941, standard deviation 0.335
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   145    105.0    0.322     2
#      2    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.323 sec (0.272 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 54.59333 stdev: 17.83296
# Best fitness: 105.00000 - size: (3, 8) - species 1 - id 1365
# Average adjusted fitness: 0.217
# Mean genetic distance 2.163, standard deviation 0.442
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    85    105.0    0.316     3
#      2    1    65     50.0    0.118     0
# Total extinctions: 0
# Generation time: 0.247 sec (0.269 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 54.46000 stdev: 18.92322
# Best fitness: 105.00000 - size: (3, 8) - species 2 - id 1365
# Average adjusted fitness: 0.520
# Mean genetic distance 2.046, standard deviation 0.402
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    85    101.0    0.512     4
#      2    2    65    105.0    0.528     0
# Total extinctions: 0
# Generation time: 0.270 sec (0.271 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 56.95333 stdev: 19.33264
# Best fitness: 105.00000 - size: (3, 8) - species 2 - id 1365
# Average adjusted fitness: 0.449
# Mean genetic distance 1.912, standard deviation 0.414
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    63    102.0    0.438     5
#      2    3    87    105.0    0.461     1
# Total extinctions: 0
# Generation time: 0.263 sec (0.271 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 58.46000 stdev: 18.32944
# Best fitness: 105.00000 - size: (3, 8) - species 2 - id 1365
# Average adjusted fitness: 0.358
# Mean genetic distance 1.932, standard deviation 0.418
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   116    102.0    0.328     6
#      2    4    34    105.0    0.387     2
# Total extinctions: 0
# Generation time: 0.254 sec (0.269 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 61.70000 stdev: 16.94412
# Best fitness: 105.00000 - size: (3, 8) - species 2 - id 1365
# Average adjusted fitness: 0.403
# Mean genetic distance 1.909, standard deviation 0.479
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   106    103.0    0.410     7
#      2    5    44    105.0    0.397     3
# Total extinctions: 0
# Generation time: 0.263 sec (0.269 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 57.49333 stdev: 19.57541
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.346
# Mean genetic distance 1.940, standard deviation 0.462
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   101    108.0    0.321     0
#      2    6    49    105.0    0.371     4
# Total extinctions: 0
# Generation time: 0.254 sec (0.265 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 63.31333 stdev: 18.40766
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.417
# Mean genetic distance 1.829, standard deviation 0.427
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    85    108.0    0.402     1
#      2    7    65    105.0    0.433     5
# Total extinctions: 0
# Generation time: 0.254 sec (0.265 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 57.74667 stdev: 19.04142
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.338
# Mean genetic distance 1.836, standard deviation 0.422
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    67    108.0    0.345     2
#      2    8    83    105.0    0.331     6
# Total extinctions: 0
# Generation time: 0.263 sec (0.265 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 60.80000 stdev: 18.88597
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.379
# Mean genetic distance 1.936, standard deviation 0.423
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    70    108.0    0.383     3
#      2    9    80    105.0    0.376     7
# Total extinctions: 0
# Generation time: 0.238 sec (0.263 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 59.39333 stdev: 19.68989
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.360
# Mean genetic distance 2.000, standard deviation 0.461
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    68    108.0    0.355     4
#      2   10    81    105.0    0.365     8
#      3    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.263 sec (0.257 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 59.26667 stdev: 19.77664
# Best fitness: 108.00000 - size: (4, 6) - species 1 - id 2575
# Average adjusted fitness: 0.270
# Mean genetic distance 2.194, standard deviation 0.579
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    69    108.0    0.349     5
#      2   11    49    105.0    0.370     9
#      3    1    32     39.0    0.092     0
# Total extinctions: 0
# Generation time: 0.254 sec (0.258 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 59.25333 stdev: 20.31721
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.549
# Mean genetic distance 2.085, standard deviation 0.540
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    49    106.0    0.536     6
#      2   12    39    105.0    0.573    10
#      3    2    63    108.0    0.538     0
# Total extinctions: 0
# Generation time: 0.263 sec (0.257 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 60.75497 stdev: 20.91894
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.377
# Mean genetic distance 1.986, standard deviation 0.513
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    71    104.0    0.376     7
#      2   13    27    106.0    0.370     0
#      3    3    53    108.0    0.385     1
# Total extinctions: 0
# Generation time: 0.254 sec (0.256 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 61.88079 stdev: 20.63204
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.561
# Mean genetic distance 1.958, standard deviation 0.514
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    34    107.0    0.554     8
#      2   14    59    106.0    0.559     1
#      3    4    57    108.0    0.571     2
# Total extinctions: 0
# Generation time: 0.270 sec (0.258 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 59.94000 stdev: 20.48422
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.486
# Mean genetic distance 2.050, standard deviation 0.550
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    43    107.0    0.500     9
#      2   15    44    105.0    0.466     2
#      3    5    63    108.0    0.491     3
# Total extinctions: 0
# Generation time: 0.248 sec (0.256 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 59.03333 stdev: 20.50965
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.355
# Mean genetic distance 2.015, standard deviation 0.598
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    61    107.0    0.311    10
#      2   16    27    105.0    0.396     3
#      3    6    63    108.0    0.358     4
# Total extinctions: 0
# Generation time: 0.232 sec (0.254 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 59.13907 stdev: 21.62015
# Best fitness: 108.00000 - size: (4, 6) - species 3 - id 2575
# Average adjusted fitness: 0.328
# Mean genetic distance 2.031, standard deviation 0.617
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    32    107.0    0.433    11
#      2   17    51    105.0    0.198     4
#      3    7    68    108.0    0.351     5
# Total extinctions: 0
# Generation time: 0.270 sec (0.255 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 63.39073 stdev: 20.81135
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.541
# Mean genetic distance 1.965, standard deviation 0.574
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    29    109.0    0.577     0
#      2   18    63    106.0    0.526     5
#      3    8    59    108.0    0.521     6
# Total extinctions: 0
# Generation time: 0.254 sec (0.255 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 58.91391 stdev: 21.30353
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.355
# Mean genetic distance 1.982, standard deviation 0.566
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    29    109.0    0.375     1
#      2   19    60    106.0    0.320     6
#      3    9    61    108.0    0.368     7
# Total extinctions: 0
# Generation time: 0.263 sec (0.257 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 61.40000 stdev: 21.75714
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.385
# Mean genetic distance 1.949, standard deviation 0.617
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    35    109.0    0.401     2
#      2   20    53    106.0    0.381     7
#      3   10    63    108.0    0.373     8
# Total extinctions: 0
# Generation time: 0.238 sec (0.255 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 60.70199 stdev: 21.36494
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.471
# Mean genetic distance 1.905, standard deviation 0.569
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    36    109.0    0.477     3
#      2   21    49    106.0    0.487     8
#      3   11    65    108.0    0.450     9
# Total extinctions: 0
# Generation time: 0.248 sec (0.254 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 59.49333 stdev: 20.92136
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.355
# Mean genetic distance 1.867, standard deviation 0.631
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    40    109.0    0.326     4
#      2   22    59    106.0    0.391     9
#      3   12    51    108.0    0.349    10
# Total extinctions: 0
# Generation time: 0.248 sec (0.252 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 62.01333 stdev: 20.68751
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.395
# Mean genetic distance 1.897, standard deviation 0.656
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    48    109.0    0.434     5
#      2   23    47    106.0    0.350    10
#      3   13    54    108.0    0.401    11
# Total extinctions: 0
# Generation time: 0.238 sec (0.251 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 58.32886 stdev: 21.89034
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.411
# Mean genetic distance 1.862, standard deviation 0.681
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    46    109.0    0.440     6
#      2   24    47    106.0    0.382    11
#      3   14    56    108.0    0.410    12
# Total extinctions: 0
# Generation time: 0.232 sec (0.247 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 62.25503 stdev: 20.03492
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.395
# Mean genetic distance 1.864, standard deviation 0.648
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    44    109.0    0.440     7
#      2   25    56    106.0    0.373    12
#      3   15    50    108.0    0.371    13
# Total extinctions: 0
# Generation time: 0.254 sec (0.248 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 59.40667 stdev: 21.07419
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.359
# Mean genetic distance 1.851, standard deviation 0.635
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    41    109.0    0.410     8
#      2   26    58    106.0    0.322    13
#      3   16    51    108.0    0.346    14
# Total extinctions: 0
# Generation time: 0.232 sec (0.248 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 60.76000 stdev: 21.87470
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.560
# Mean genetic distance 1.882, standard deviation 0.647
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    38    109.0    0.578     9
#      2   27    58    106.0    0.530    14
#      3   17    55    108.0    0.572    15
# Total extinctions: 0
# Generation time: 0.239 sec (0.245 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 62.14570 stdev: 21.15299
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.564
# Mean genetic distance 1.807, standard deviation 0.625
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    44    109.0    0.577    10
#      2   28    52    106.0    0.535    15
#      3   18    55    108.0    0.580    16
# Total extinctions: 0
# Generation time: 0.250 sec (0.244 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 59.54967 stdev: 22.24597
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.521
# Mean genetic distance 1.828, standard deviation 0.642
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    44    109.0    0.546    11
#      2   29    52    106.0    0.495    16
#      3   19    55    108.0    0.522    17
# Total extinctions: 0
# Generation time: 0.250 sec (0.243 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 60.41722 stdev: 22.54836
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.556
# Mean genetic distance 1.895, standard deviation 0.639
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    45    109.0    0.590    12
#      2   30    52    108.0    0.526     0
#      3   20    54    108.0    0.552    18
# Total extinctions: 0
# Generation time: 0.233 sec (0.242 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 60.98675 stdev: 21.52251
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.561
# Mean genetic distance 1.910, standard deviation 0.588
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42    44    109.0    0.586    13
#      2   31    58    108.0    0.540     1
#      3   21    49    108.0    0.556    19
# Total extinctions: 0
# Generation time: 0.266 sec (0.244 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 58.92715 stdev: 21.44054
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.368
# Mean genetic distance 1.994, standard deviation 0.633
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43    50    109.0    0.384    14
#      2   32    49    108.0    0.345     2
#      3   22    51    108.0    0.374    20
# Total extinctions: 0
# Generation time: 0.283 sec (0.248 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 59.50667 stdev: 23.03729
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.381
# Mean genetic distance 1.960, standard deviation 0.629
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    38    109.0    0.373    15
#      2   33    61    108.0    0.351     3
#      3   23    51    108.0    0.419    21
# Total extinctions: 0
# Generation time: 0.285 sec (0.252 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 60.59333 stdev: 21.14083
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.389
# Mean genetic distance 1.869, standard deviation 0.641
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    36    109.0    0.393    16
#      2   34    57    108.0    0.362     4
#      3   24    57    108.0    0.414    22
# Total extinctions: 0
# Generation time: 0.252 sec (0.254 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 62.47333 stdev: 21.44192
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.404
# Mean genetic distance 1.790, standard deviation 0.648
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    47    109.0    0.464    17
#      2   35    51    108.0    0.367     5
#      3   25    52    108.0    0.382    23
# Total extinctions: 0
# Generation time: 0.231 sec (0.252 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 63.64000 stdev: 21.51628
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.413
# Mean genetic distance 1.791, standard deviation 0.686
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    48    109.0    0.468    18
#      2   36    54    108.0    0.389     6
#      3   26    48    108.0    0.381    24
# Total extinctions: 0
# Generation time: 0.277 sec (0.256 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 59.28667 stdev: 21.29173
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.394
# Mean genetic distance 1.794, standard deviation 0.692
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    56    109.0    0.383    19
#      2   37    38    108.0    0.384     7
#      3   27    56    108.0    0.415    25
# Total extinctions: 0
# Generation time: 0.257 sec (0.258 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 62.75333 stdev: 22.27343
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.486
# Mean genetic distance 1.824, standard deviation 0.658
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49    52    109.0    0.524    20
#      2   38    40    108.0    0.441     8
#      3   28    58    108.0    0.494    26
# Total extinctions: 0
# Generation time: 0.247 sec (0.258 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 59.52667 stdev: 21.20273
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.354
# Mean genetic distance 1.814, standard deviation 0.641
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50    37    109.0    0.425    21
#      2   39    59    108.0    0.306     9
#      3   29    54    108.0    0.333    27
# Total extinctions: 0
# Generation time: 0.237 sec (0.257 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 58.02667 stdev: 21.50812
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.345
# Mean genetic distance 1.830, standard deviation 0.652
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51    35    109.0    0.390    22
#      2   40    61    108.0    0.290    10
#      3   30    55    108.0    0.355    28
# Total extinctions: 0
# Generation time: 0.266 sec (0.260 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 59.76159 stdev: 20.50221
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.376
# Mean genetic distance 1.866, standard deviation 0.703
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52    43    109.0    0.424    23
#      2   41    59    108.0    0.361    11
#      3   31    49    108.0    0.342    29
# Total extinctions: 0
# Generation time: 0.250 sec (0.258 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 59.65563 stdev: 21.35014
# Best fitness: 109.00000 - size: (3, 5) - species 1 - id 4329
# Average adjusted fitness: 0.367
# Mean genetic distance 1.950, standard deviation 0.717
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53    24    109.0    0.423    24
#      2   42    69    108.0    0.286    12
#      3   32    57    108.0    0.391    30
# Total extinctions: 0
# Generation time: 0.266 sec (0.257 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 59.87333 stdev: 22.05910
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
#
# Species 3 with 57 members is stagnated: removing it
# Average adjusted fitness: 0.385
# Mean genetic distance 1.466, standard deviation 0.443
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54    49    109.0    0.420    25
#      2   43   101    109.0    0.349     0
# Total extinctions: 0
# Generation time: 0.233 sec (0.252 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 58.73333 stdev: 19.08251
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.356
# Mean genetic distance 1.519, standard deviation 0.467
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55    53    109.0    0.383    26
#      2   44    97    109.0    0.330     1
# Total extinctions: 0
# Generation time: 0.246 sec (0.251 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 57.84667 stdev: 20.13380
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.514
# Mean genetic distance 1.643, standard deviation 0.533
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56    53    109.0    0.516    27
#      2   45    97    109.0    0.511     2
# Total extinctions: 0
# Generation time: 0.237 sec (0.252 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 59.40000 stdev: 20.04828
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.528
# Mean genetic distance 1.997, standard deviation 0.735
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57    67    109.0    0.563    28
#      2   46    70    109.0    0.494     3
#      4    0    13       --       --     0
# Total extinctions: 0
# Generation time: 0.254 sec (0.249 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 57.67333 stdev: 19.82776
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.383
# Mean genetic distance 2.140, standard deviation 0.554
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58    38    109.0    0.427    29
#      2   47    50    109.0    0.357     4
#      4    1    61     90.0    0.366     0
# Total extinctions: 0
# Generation time: 0.247 sec (0.248 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 59.25503 stdev: 20.23923
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.362
# Mean genetic distance 2.056, standard deviation 0.600
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    42    109.0    0.409    30
#      2   48    49    109.0    0.376     5
#      4    2    58    105.0    0.302     0
# Total extinctions: 0
# Generation time: 0.253 sec (0.249 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 56.68456 stdev: 21.28398
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.369
# Mean genetic distance 1.961, standard deviation 0.656
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    35    109.0    0.349    31
#      2   49    56    109.0    0.401     6
#      4    3    59    105.0    0.358     1
# Total extinctions: 0
# Generation time: 0.246 sec (0.250 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 59.26667 stdev: 22.07824
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.372
# Mean genetic distance 1.909, standard deviation 0.631
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61    46    109.0    0.487    32
#      2   50    55    109.0    0.359     7
#      4    4    49    105.0    0.270     2
# Total extinctions: 0
# Generation time: 0.264 sec (0.250 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 60.84667 stdev: 21.60362
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.377
# Mean genetic distance 1.943, standard deviation 0.567
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62    39    109.0    0.445    33
#      2   51    74    109.0    0.345     8
#      4    5    36    108.0    0.342     0
# Total extinctions: 0
# Generation time: 0.252 sec (0.250 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 59.49664 stdev: 20.73567
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.354
# Mean genetic distance 1.882, standard deviation 0.642
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63    55    109.0    0.425    34
#      2   52    62    109.0    0.361     9
#      4    6    32    105.0    0.276     1
# Total extinctions: 0
# Generation time: 0.250 sec (0.248 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 60.94631 stdev: 20.59478
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.374
# Mean genetic distance 1.847, standard deviation 0.628
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    50    109.0    0.413    35
#      2   53    65    109.0    0.354    10
#      4    7    36    105.0    0.354     2
# Total extinctions: 0
# Generation time: 0.250 sec (0.250 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 57.74172 stdev: 21.06925
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.335
# Mean genetic distance 1.885, standard deviation 0.606
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65    50    109.0    0.371    36
#      2   54    44    109.0    0.313    11
#      4    8    57    105.0    0.323     3
# Total extinctions: 0
# Generation time: 0.250 sec (0.250 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 61.72848 stdev: 19.96584
# Best fitness: 109.00000 - size: (3, 5) - species 2 - id 4329
# Average adjusted fitness: 0.402
# Mean genetic distance 1.818, standard deviation 0.669
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66    35    109.0    0.446    37
#      2   55    62    109.0    0.379    12
#      4    9    54    105.0    0.380     4
# Total extinctions: 0
# Generation time: 0.250 sec (0.252 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 59.50993 stdev: 21.34667
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.352
# Mean genetic distance 1.819, standard deviation 0.640
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    38    110.0    0.363     0
#      2   56    62    109.0    0.388    13
#      4   10    51    106.0    0.305     5
# Total extinctions: 0
# Generation time: 0.266 sec (0.253 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 61.14570 stdev: 21.29465
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.373
# Mean genetic distance 1.827, standard deviation 0.602
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68    41    110.0    0.369     1
#      2   57    65    109.0    0.382    14
#      4   11    45    106.0    0.367     6
# Total extinctions: 0
# Generation time: 0.283 sec (0.256 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 58.10596 stdev: 22.05146
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.340
# Mean genetic distance 1.970, standard deviation 0.633
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    47    110.0    0.362     2
#      2   58    59    109.0    0.304    15
#      4   12    45    106.0    0.355     7
# Total extinctions: 0
# Generation time: 0.267 sec (0.258 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 57.65563 stdev: 21.04994
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.368
# Mean genetic distance 2.004, standard deviation 0.639
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70    48    110.0    0.343     3
#      2   59    59    109.0    0.383    16
#      4   13    42    106.0    0.379     8
# Total extinctions: 0
# Generation time: 0.329 sec (0.266 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 58.93289 stdev: 21.16368
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.350
# Mean genetic distance 2.294, standard deviation 0.817
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71    40    110.0    0.313     4
#      2   60    60    109.0    0.319    17
#      4   14    44    106.0    0.419     9
#      5    0     4       --       --     0
#      6    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.237 sec (0.263 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 57.71141 stdev: 22.82566
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.436
# Mean genetic distance 2.448, standard deviation 0.789
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72    38    110.0    0.524     5
#      2   61    53    109.0    0.505    18
#      4   15    39    106.0    0.517    10
#      5    1     6     41.0    0.285     0
#      6    1    14     41.0    0.349     0
# Total extinctions: 0
# Generation time: 0.250 sec (0.263 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 59.93333 stdev: 23.20220
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.480
# Mean genetic distance 2.512, standard deviation 0.749
# Population of 149 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73    31    110.0    0.552     6
#      2   62    54    109.0    0.568    19
#      4   16    26    106.0    0.607    11
#      5    2    22     48.0    0.308     0
#      6    2    16     73.0    0.366     0
# Total extinctions: 0
# Generation time: 0.250 sec (0.263 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 60.37584 stdev: 22.19059
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.320
# Mean genetic distance 2.427, standard deviation 0.676
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   74    35    110.0    0.405     7
#      2   63    25    109.0    0.462    20
#      4   17    25    106.0    0.398    12
#      5    3    48     73.0    0.163     0
#      6    3    18     73.0    0.171     1
# Total extinctions: 0
# Generation time: 0.245 sec (0.263 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 60.80795 stdev: 21.76567
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.511
# Mean genetic distance 2.304, standard deviation 0.731
# Population of 151 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   75    27    110.0    0.514     8
#      2   64    37    109.0    0.545    21
#      4   18    24     93.0    0.502    13
#      5    4    39    109.0    0.514     0
#      6    4    24     73.0    0.480     2
# Total extinctions: 0
# Generation time: 0.238 sec (0.262 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 57.60927 stdev: 22.54884
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.516
# Mean genetic distance 2.212, standard deviation 0.785
# Population of 150 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   86    26    110.0    0.397    19
#      2   75    43    109.0    0.362    32
#      5   15    52    109.0    0.384    11
#      6   15    28     73.0    0.264    13
# Total extinctions: 0
# Generation time: 0.247 sec (0.287 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 60.66443 stdev: 22.41003
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.367
# Mean genetic distance 1.999, standard deviation 0.737
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   87    35    110.0    0.440    20
#      2   76    35    109.0    0.365    33
#      5   16    50    109.0    0.378    12
#      6   16    29     73.0    0.283    14
# Total extinctions: 0
# Generation time: 0.266 sec (0.287 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 61.91275 stdev: 20.96335
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.374
# Mean genetic distance 1.956, standard deviation 0.742
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   88    30    110.0    0.363    21
#      2   77    49    109.0    0.443    34
#      5   17    44    109.0    0.426    13
#      6   17    27     73.0    0.264    15
# Total extinctions: 0
# Generation time: 0.300 sec (0.286 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 60.72000 stdev: 21.42743
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.356
# Mean genetic distance 2.027, standard deviation 0.676
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   89    34    110.0    0.406    22
#      2   78    37    109.0    0.368    35
#      5   18    57    109.0    0.437    14
#      6   18    22     73.0    0.213    16
# Total extinctions: 0
# Generation time: 0.250 sec (0.283 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 61.22000 stdev: 21.27655
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.367
# Mean genetic distance 2.009, standard deviation 0.684
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   90    36    110.0    0.429    23
#      2   79    32    109.0    0.339    36
#      5   19    56    109.0    0.390    15
#      6   19    26     73.0    0.311    17
# Total extinctions: 0
# Generation time: 0.283 sec (0.283 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 59.23333 stdev: 22.46699
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.529
# Mean genetic distance 1.962, standard deviation 0.651
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   91    29    110.0    0.523    24
#      2   80    35    109.0    0.504    37
#      5   20    61    109.0    0.585    16
#      6   20    26     73.0    0.502    18
# Total extinctions: 0
# Generation time: 0.253 sec (0.280 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 59.09272 stdev: 21.37503
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.334
# Mean genetic distance 1.967, standard deviation 0.675
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   92    33    110.0    0.378    25
#      2   81    36    109.0    0.369    38
#      5   21    58    109.0    0.380    17
#      6   21    24     73.0    0.208    19
# Total extinctions: 0
# Generation time: 0.233 sec (0.277 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 58.40397 stdev: 20.65009
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
#
# Species 6 with 24 members is stagnated: removing it
# Average adjusted fitness: 0.360
# Mean genetic distance 1.690, standard deviation 0.508
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   93    39    110.0    0.367    26
#      2   82    49    109.0    0.370    39
#      5   22    61    109.0    0.343    18
# Total extinctions: 0
# Generation time: 0.231 sec (0.273 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 57.85235 stdev: 21.50398
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.353
# Mean genetic distance 1.706, standard deviation 0.537
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   94    35    110.0    0.409    27
#      2   83    53    109.0    0.308    40
#      5   23    61    109.0    0.341    19
# Total extinctions: 0
# Generation time: 0.217 sec (0.267 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 60.69128 stdev: 21.24415
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
#
# Species 5 with 61 members is stagnated: removing it
# Average adjusted fitness: 0.342
# Mean genetic distance 1.391, standard deviation 0.512
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   95    71    110.0    0.355    28
#      2   84    79    109.0    0.330    41
# Total extinctions: 0
# Generation time: 0.253 sec (0.253 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 60.44000 stdev: 21.82765
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.537
# Mean genetic distance 1.342, standard deviation 0.420
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   96    63    110.0    0.540    29
#      2   85    87    109.0    0.534    42
# Total extinctions: 0
# Generation time: 0.246 sec (0.253 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 59.22000 stdev: 19.98128
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.507
# Mean genetic distance 1.431, standard deviation 0.495
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   97    59    110.0    0.541    30
#      2   86    91    109.0    0.474    43
# Total extinctions: 0
# Generation time: 0.267 sec (0.253 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 59.27333 stdev: 20.61064
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.346
# Mean genetic distance 1.469, standard deviation 0.498
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   98    61    110.0    0.327    31
#      2   87    89    109.0    0.364    44
# Total extinctions: 0
# Generation time: 0.267 sec (0.250 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 60.24667 stdev: 20.81856
# Best fitness: 110.00000 - size: (3, 5) - species 1 - id 9870
# Average adjusted fitness: 0.370
# Mean genetic distance 1.474, standard deviation 0.408
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   99    59    110.0    0.410    32
#      2   88    91    109.0    0.329    45
# Total extinctions: 0
# Generation time: 0.300 sec (0.255 average)

# %%
# Show the best individual and its accuracy on test data
print(f"*Best genome*\n{winner}")

winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
num_of_correct_predictions = 0
for input_example, correct_output in zip(test_x, test_y):
    output = winner_net.activate(input_example)
    prediction = np.argmax(output)
        
    if prediction == correct_output:
        num_of_correct_predictions += 1
    
print("\nTotal accuracy on the test data:", num_of_correct_predictions / len(test_y))

# Render the best network
node_names = {-1:"x1", -2: "x2", -3: "x3", -4: "x4", 0:"setosa", 1:"virginica", 2:"versicolor"}
visualize.draw_net(
    config,
    genome=winner,
    node_names=node_names,
    show_disabled=True,
    prune_unused=False
) 

# Plot the statistics
visualize.plot_stats(stats, ylog=False, view=True)
visualize.plot_species(stats, view=True)
# Out:
# *Best genome*
# Key: 9870
# Fitness: 110.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.6705023523429592, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.9109774963515869, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-4.428404622309877, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-4, 1), weight=-1.0112109965451523, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-5.167876617420322, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=0.7015100492285063, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=3.5341366343010376, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.528709915739771, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=2.282038611289347, enabled=False)
#
# Total accuracy on the test data: 0.9736842105263158

# %% [markdown]
# ## Domácí úkol - Zpětnovazební učení s využitím neuroevoluce
#
# Za domácí úkol budete mít vyzkoušet si vyřešit některá prostředí z knihovny [Gymnasium](https://gymnasium.farama.org/). Vyzkoušet můžete buď NEAT (v takovém případě můžete použít třeba knihovnu, kterou jsme si právě vyzkoušeli, jen nezapomeňte přizpůsobit konfigurační soubor, fitness a tak podobně), vyvíjet jen vektor vah fixní sítě, nebo cokoli vás napadne.
#
# [Detailní zadání](https://kam.mff.cuni.cz/~lorenc/teach/23-24/PIA/homeworks-neuroevolution.html) je možno najít na stránkách cvičení.
