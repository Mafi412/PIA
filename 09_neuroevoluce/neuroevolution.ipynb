# %% [markdown]
# # Neuroevoluce
#
# Pomocí evolučních algoritmů můžeme vyvíjet i celé neuronové sítě. Buď můžeme evolvovat váhy mezi neurony, strukturu sítě nebo obojí najednou. Nejprve se podíváme, jak naimplementovat jednoduchý algoritmus pro evoluci vah, následně si zkusíme i evoluci vah a struktury sítě najednou pomocí algoritmu NEAT.
#
# ## Evoluce vah
#
# Evoluce vah je jednoduchá, stačí naimplementovat jednoduchou neuronovou síť, které umíme nastavit parametry. Náš jedinec v evoluci bude jeden dlouhý vektor, který bude reprezentovat váhy mezi vrstvami v neuronové síti. Při vyhodnocování tedy nastavíme síti váhy podle daného jedince a spočítáme její výstup. Zkusíme si tímto způsobem implementovat klasifikaci na našem oblíbeném datasetu iris.

# %%
import numpy as np

from sklearn import datasets, model_selection

from deap import algorithms, creator, base, cma, tools

# %% [markdown]
# Začneme tím, že si připravíme jednoduchou implementaci neuronové sítě. Při inicializaci nastavíme vrstvy, jejich velikosti a také jejich aktivace, jelikož každá vrstva může mít svou vlastní aktivační funkci.
#
# Dále budeme potřebovat jednoho dlouhého linárního jedince všech vah rozdělit na váhové matice. To uděláme tak, že budeme brát vždy velikost akutální a následující vrstvy, na základě toho vezmeme odpovídající část jedince a vytvoříme z něj matici vah. Zároveň musíme přidat biasy, takže velikost aktuální vrstvy zvětšíme ještě o 1.
#
# Nakonec bude potřeba ještě funkce pro evaluaci sítě, která vytvořenou síť vyhodnotí tak, že pro každou vrstvu použije odpovídající aktivaci a vrátí nám výstup sítě.

# %%
class NeuralNetwork: 
    def __init__(self, layer_sizes, activations):
        self.layer_sizes = layer_sizes
        self.layers = None

        # Checking, whether the number of activations corresponds to the number of layers
        if len(list(activations)) != len(layer_sizes) - 1:
            raise AttributeError("Number of activations does not match number of layers")
        
        self.activations = list(activations)
        self.vectorized_net = None


    # Returns complete nuber of parameters of the network
    def vectorized_size(self):
        return sum(map(lambda x: (x[0] + 1) * x[1], zip(self.layer_sizes, self.layer_sizes[1:])))


    # Sets weights of the network using the values given by the linear individual
    def set_weights(self, vectorized_net):
        
        # Checking, whether the sizes match
        if len(vectorized_net) != self.vectorized_size():
            raise AttributeError(
                f"Length of vector does not match vectorized_size: {len(vectorized_net)} != {self.vectorized_size()}"
            )

        self.vectorized_net = vectorized_net
        self.layers = []
        sum_sizes = 0 # Sum of sizes of the previous layers (number of already processed elements)
        
        # Go through layers and set weight matrix between the current one and the following one
        # using the corresponding values from the linear indivudual.
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
            number_of_corresponding_elements = (input_layer_size + 1) * output_layer_size
            
            layer = vectorized_net[sum_sizes:(sum_sizes + number_of_corresponding_elements)]
            self.layers.append(np.reshape(layer, newshape=(input_layer_size + 1, output_layer_size))) # Reshaping to the correct format
            
            sum_sizes += number_of_corresponding_elements


    # Evaluation of the network
    def eval_network(self, inputs):
        activations = inputs
        
        for activation_function, layer in zip(self.activations, self.layers):
            activations_1 = np.append(np.array([1.0]), activations)  # Extending the input vector by a constant one to be multiplied by the bias part of the weights
            activations = activation_function(np.dot(activations_1, layer))

        return activations

# %% [markdown]
# Nyní si akorát načteme data a rozdělíme si je na trénovací a testovací.

# %%
iris = datasets.load_iris()
train_x, test_x, train_y, test_y = model_selection.train_test_split(iris.data, iris.target)

# %% [markdown]
# Musíme si ještě definovat fitness funkci, což bude pouze vyhodnocení sítě na datech, kdy vždy vybereme jako predikovanou třídu tu s maximální pravděpodobností a spočítáme pak celkovou accuracy. Zároveň si definujeme vlastní lineární a relu aktivace.

# %%
def relu(x):
    return np.maximum(0, x)

def linear(x):
    return x

def fitness(net, ind, X, y):
    net.set_weights(ind)
    
    acc = 0
    for xi, yi in zip(X, y):
        if np.argmax(net.eval_network(xi)) == yi:
            acc += 1
    
    return acc / len(y),

# %% [markdown]
# Pro samotné nastavení vah neuronové sítě použíjeme algoritmus CMA-ES, což je evoluční strategie, která je velmi dobrá na úlohy spojité optimalizace, kterou máme i zde. V evoluční strategii se většinou nevyskytuje křížení, ale místo něj se klade důraz na mutaci. Zde se používá námi známá gaussovská mutace. Evoluční strategii používáme také proto, že nám umožňuje váhy měnit korelovaně, protože si pamatuje celou kovariační matici, ze které generuje jedince. Klasická evoluce umí měnit váhy jen nezávisle na sobě, a dává proto horší výsledky. CMA-ES je implementována v knihovně deap, a je tedy snadné ji použít.

# %%
net = NeuralNetwork([4, 5, 3], [relu, linear])
ind_size = net.vectorized_size()    
    
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("evaluate", lambda ind, X, y: fitness(net, ind, X, y), X=train_x, y=train_y)

strategy = cma.Strategy(centroid=[0.0] * ind_size, sigma=0.1, lambda_= 5 * ind_size)
toolbox.register("generate", strategy.generate, creator.Individual)
toolbox.register("update", strategy.update)

hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

_ = algorithms.eaGenerateUpdate(toolbox, ngen=250, stats=stats, halloffame=hof)
# Out:
# gen	nevals	avg    	std      	min	max
# 0  	215   	0.34485	0.0952697	0  	0.6875
# 1  	215   	0.353945	0.127056 	0  	0.821429
# 2  	215   	0.357475	0.109738 	0  	0.705357
# 3  	215   	0.373547	0.116496 	0  	0.696429
# 4  	215   	0.374211	0.0908977	0.116071	0.848214
# 5  	215   	0.389909	0.118953 	0       	0.696429
# 6  	215   	0.391985	0.121957 	0       	0.75
# 7  	215   	0.401952	0.137252 	0       	0.732143
# 8  	215   	0.405565	0.136054 	0.0625  	0.696429
# 9  	215   	0.419186	0.139639 	0.00892857	0.696429
# 10 	215   	0.406686	0.156313 	0.00892857	0.830357
# 11 	215   	0.420515	0.160397 	0         	0.75
# 12 	215   	0.414286	0.155396 	0         	0.714286
# 13 	215   	0.439452	0.155871 	0.0178571 	0.955357
# 14 	215   	0.429277	0.157639 	0.00892857	0.821429
# 15 	215   	0.452409	0.173125 	0         	0.821429
# 16 	215   	0.507517	0.172032 	0.0357143 	0.964286
# 17 	215   	0.497093	0.166531 	0.142857  	0.919643
# 18 	215   	0.489078	0.166109 	0         	0.830357
# 19 	215   	0.508679	0.17273  	0         	0.982143
# 20 	215   	0.528322	0.167628 	0.0803571 	0.839286
# 21 	215   	0.512749	0.165321 	0.223214  	0.875
# 22 	215   	0.530731	0.173953 	0.0892857 	0.991071
# 23 	215   	0.53044 	0.178538 	0.00892857	1
# 24 	215   	0.558347	0.163384 	0.107143  	0.75
# 25 	215   	0.571968	0.161472 	0.0892857 	0.964286
# 26 	215   	0.578654	0.164237 	0.0535714 	0.955357
# 27 	215   	0.588704	0.155769 	0.0803571 	0.973214
# 28 	215   	0.596927	0.146358 	0         	0.821429
# 29 	215   	0.61441 	0.141808 	0.214286  	0.696429
# 30 	215   	0.633015	0.126773 	0.303571  	0.866071
# 31 	215   	0.629444	0.135832 	0.0357143 	0.928571
# 32 	215   	0.640075	0.119981 	0.0803571 	0.991071
# 33 	215   	0.641071	0.11454  	0.303571  	0.705357
# 34 	215   	0.648048	0.116141 	0.241071  	0.9375
# 35 	215   	0.651827	0.108486 	0.214286  	0.928571
# 36 	215   	0.657018	0.107596 	0.205357  	0.973214
# 37 	215   	0.663704	0.0964829	0.330357  	0.964286
# 38 	215   	0.660133	0.104517 	0.276786  	0.946429
# 39 	215   	0.67554 	0.0776138	0.330357  	0.955357
# 40 	215   	0.665449	0.089156 	0.303571  	0.714286
# 41 	215   	0.666985	0.0914905	0.303571  	0.803571
# 42 	215   	0.681022	0.0658111	0.303571  	0.696429
# 43 	215   	0.683846	0.063328 	0.330357  	0.892857
# 44 	215   	0.688704	0.0397207	0.330357  	0.696429
# 45 	215   	0.683846	0.0561993	0.330357  	0.696429
# 46 	215   	0.687749	0.0494461	0.330357  	0.776786
# 47 	215   	0.691196	0.0358084	0.366071  	0.696429
# 48 	215   	0.691362	0.0359975	0.330357  	0.696429
# 49 	215   	0.688538	0.0509465	0.321429  	0.919643
# 50 	215   	0.686836	0.045006 	0.330357  	0.696429
# 51 	215   	0.684551	0.0595861	0.330357  	0.696429
# 52 	215   	0.688289	0.0503875	0.330357  	0.696429
# 53 	215   	0.692691	0.0347797	0.330357  	0.696429
# 54 	215   	0.690615	0.038429 	0.366071  	0.696429
# 55 	215   	0.693895	0.0234866	0.410714  	0.696429
# 56 	215   	0.692608	0.0297354	0.366071  	0.696429
# 57 	215   	0.696387	0.000607506	0.6875    	0.696429
# 58 	215   	0.696221	0.00159762 	0.678571  	0.696429
# 59 	215   	0.694518	0.0243734  	0.339286  	0.696429
# 60 	215   	0.696304	0.00182252 	0.669643  	0.696429
# 61 	215   	0.694601	0.0249658  	0.330357  	0.696429
# 62 	215   	0.692733	0.0353079  	0.330357  	0.696429
# 63 	215   	0.696013	0.00549838 	0.616071  	0.696429
# 64 	215   	0.695847	0.0123761  	0.526786  	0.758929
# 65 	215   	0.696055	0.00347797 	0.660714  	0.696429
# 66 	215   	0.696221	0.00218566 	0.669643  	0.696429
# 67 	215   	0.692068	0.0344767  	0.366071  	0.696429
# 68 	215   	0.691985	0.035609   	0.330357  	0.785714
# 69 	215   	0.69211 	0.0309037  	0.348214  	0.696429
# 70 	215   	0.694186	0.0253596  	0.330357  	0.696429
# 71 	215   	0.693978	0.0172101  	0.535714  	0.696429
# 72 	215   	0.696013	0.00410899 	0.642857  	0.696429
# 73 	215   	0.690075	0.0429372  	0.330357  	0.696429
# 74 	215   	0.696221	0.00159762 	0.678571  	0.696429
# 75 	215   	0.690905	0.0460804  	0.0714286 	0.696429
# 76 	215   	0.693314	0.0309105  	0.366071  	0.696429
# 77 	215   	0.693148	0.0330392  	0.339286  	0.696429
# 78 	215   	0.689203	0.0441593  	0.366071  	0.696429
# 79 	215   	0.693646	0.0278253  	0.303571  	0.696429
# 80 	215   	0.692193	0.0358883  	0.366071  	0.696429
# 81 	215   	0.690947	0.0404233  	0.339286  	0.696429
# 82 	215   	0.693854	0.0266408  	0.330357  	0.696429
# 83 	215   	0.695847	0.00618255 	0.607143  	0.696429
# 84 	215   	0.68696 	0.0518916  	0.330357  	0.696429
# 85 	215   	0.693605	0.0244063  	0.366071  	0.696429
# 86 	215   	0.690615	0.0399337  	0.330357  	0.696429
# 87 	215   	0.692068	0.035588   	0.348214  	0.696429
# 88 	215   	0.686047	0.0567094  	0.330357  	0.696429
# 89 	215   	0.69593 	0.00670729 	0.598214  	0.696429
# 90 	215   	0.695058	0.0120551  	0.544643  	0.696429
# 91 	215   	0.695432	0.013983   	0.491071  	0.696429
# 92 	215   	0.696138	0.00326624 	0.651786  	0.696429
# 93 	215   	0.69564 	0.0115426  	0.526786  	0.696429
# 94 	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 95 	215   	0.694726	0.0249077  	0.330357  	0.696429
# 96 	215   	0.696346	0.000857133	0.6875    	0.696429
# 97 	215   	0.694726	0.0249077  	0.330357  	0.696429
# 98 	215   	0.696346	0.000857133	0.6875    	0.696429
# 99 	215   	0.694684	0.0243097  	0.339286  	0.696429
# 100	215   	0.695266	0.0164111  	0.455357  	0.696429
# 101	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 102	215   	0.696387	0.000607506	0.6875    	0.696429
# 103	215   	0.6951  	0.0128198  	0.526786  	0.696429
# 104	215   	0.690282	0.0430579  	0.330357  	0.696429
# 105	215   	0.693397	0.0311577  	0.330357  	0.696429
# 106	215   	0.691404	0.0401008  	0.330357  	0.696429
# 107	215   	0.690615	0.0432071  	0.330357  	0.696429
# 108	215   	0.693812	0.0257377  	0.330357  	0.696429
# 109	215   	0.696387	0.000607506	0.6875    	0.696429
# 110	215   	0.691071	0.0429608  	0.330357  	0.696429
# 111	215   	0.689535	0.0455507  	0.330357  	0.696429
# 112	215   	0.690615	0.0434809  	0.330357  	0.696429
# 113	215   	0.691528	0.0412688  	0.330357  	0.696429
# 114	215   	0.691279	0.0419516  	0.330357  	0.696429
# 115	215   	0.695889	0.00789757 	0.580357  	0.696429
# 116	215   	0.694643	0.0249317  	0.330357  	0.696429
# 117	215   	0.696346	0.00121501 	0.678571  	0.696429
# 118	215   	0.693231	0.032675   	0.330357  	0.696429
# 119	215   	0.694601	0.0249658  	0.330357  	0.696429
# 120	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 121	215   	0.692525	0.0354271  	0.330357  	0.696429
# 122	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 123	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 124	215   	0.694518	0.0249893  	0.330357  	0.696429
# 125	215   	0.696304	0.00182252 	0.669643  	0.696429
# 126	215   	0.696096	0.00486005 	0.625     	0.696429
# 127	215   	0.693605	0.0291934  	0.375     	0.696429
# 128	215   	0.69348 	0.0269     	0.339286  	0.696429
# 129	215   	0.695307	0.0109201  	0.544643  	0.696429
# 130	215   	0.693854	0.0241745  	0.375     	0.696429
# 131	215   	0.690365	0.0415179  	0.330357  	0.696429
# 132	215   	0.689203	0.0496532  	0.330357  	0.696429
# 133	215   	0.695972	0.00552872 	0.616071  	0.696429
# 134	215   	0.691944	0.0383368  	0.3125    	0.696429
# 135	215   	0.692899	0.0321024  	0.330357  	0.696429
# 136	215   	0.694518	0.0249745  	0.330357  	0.696429
# 137	215   	0.694643	0.0249317  	0.330357  	0.696429
# 138	215   	0.693189	0.0334725  	0.330357  	0.696429
# 139	215   	0.691819	0.0384428  	0.330357  	0.696429
# 140	215   	0.695183	0.0170261  	0.446429  	0.696429
# 141	215   	0.694643	0.0196032  	0.419643  	0.696429
# 142	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 143	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 144	215   	0.693605	0.02756    	0.330357  	0.696429
# 145	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 146	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 147	215   	0.694186	0.0260946  	0.330357  	0.696429
# 148	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 149	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 150	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 151	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 152	215   	0.694726	0.0249077  	0.330357  	0.696429
# 153	215   	0.694643	0.0249317  	0.330357  	0.696429
# 154	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 155	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 156	215   	0.694601	0.0249658  	0.330357  	0.696429
# 157	215   	0.694394	0.0251791  	0.330357  	0.696429
# 158	215   	0.696304	0.00135588 	0.678571  	0.696429
# 159	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 160	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 161	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 162	215   	0.696013	0.00607506 	0.607143  	0.696429
# 163	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 164	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 165	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 166	215   	0.694726	0.0249077  	0.330357  	0.696429
# 167	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 168	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 169	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 170	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 171	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 172	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 173	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 174	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 175	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 176	215   	0.696304	0.00182252 	0.669643  	0.696429
# 177	215   	0.696387	0.000607506	0.6875    	0.696429
# 178	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 179	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 180	215   	0.696387	0.000607506	0.6875    	0.696429
# 181	215   	0.696387	0.000607506	0.6875    	0.696429
# 182	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 183	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 184	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 185	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 186	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 187	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 188	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 189	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 190	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 191	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 192	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 193	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 194	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 195	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 196	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 197	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 198	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 199	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 200	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 201	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 202	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 203	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 204	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 205	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 206	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 207	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 208	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 209	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 210	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 211	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 212	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 213	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 214	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 215	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 216	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 217	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 218	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 219	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 220	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 221	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 222	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 223	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 224	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 225	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 226	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 227	215   	0.696138	0.00369251 	0.642857  	0.696429
# 228	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 229	215   	0.69593 	0.00729007 	0.589286  	0.696429
# 230	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 231	215   	0.696346	0.000857133	0.6875    	0.696429
# 232	215   	0.696262	0.00243002 	0.660714  	0.696429
# 233	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 234	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 235	215   	0.696387	0.000607506	0.6875    	0.696429
# 236	215   	0.696387	0.000607506	0.6875    	0.696429
# 237	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 238	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 239	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 240	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 241	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 242	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 243	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 244	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 245	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 246	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 247	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 248	215   	0.696429	1.11022e-16	0.696429  	0.696429
# 249	215   	0.696429	1.11022e-16	0.696429  	0.696429

# %% [markdown]
# Na závěr si zkusíme otestovat síť na testovacích datech a změřit na nich accuracy.

# %%
accuracy = fitness(net, hof[0], test_x, test_y)[0]
print("Achieved accuracy:", accuracy)
# Out:
# Achieved accuracy: 0.9736842105263158

# %% [markdown]
# ## NEAT
#
# Zkusíme se podívat na algoritmus NEAT na příkladu s datasetem iris a zkusíme pro něj najít co nejvhodnější síť, která bude umět data pokud možno co nejlépe klasifikovat. Samotná implementace algorimtu není vůbec jednoduchá, ale naštěstí v pythonu existuje knihovna neat-python, kde už tu práci někdo udělal za nás (instalujeme pomocí `pip install neat-python`). Knihovna má trochu jiný interface, než na co jsme zvyklí, ale není složité se jí naučit používat. Nastavení parametrů algoritmu se načítá ze zvláštního souboru *config-feedforward*. Dokumentace k jeho formátování se nachází [zde](https://neat-python.readthedocs.io/en/latest/config_file.html). Potom už stačí jen algoritmus spustit. Níže uvedený příklad vychází z dokumentace k [neat-python](https://github.com/CodeReclaimers/neat-python/tree/master/examples/xor) upravený pro naši klasifikaci irisů.

# %%
import neat
import visualize

# %%
# Construction and evaluation of a network in NEAT - basically a fitness function
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = 0.0
        net = neat.nn.FeedForwardNetwork.create(genome, config) 
        
        for xi, xo in zip(train_x, train_y): 
            output = net.activate(xi)
            if np.argmax(output) == xo:
                genome.fitness += 1

# %%
# Path to the configuration file
config_path = "config-feedforward"

# Load NEAT configuration
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)

# Create new population
population = neat.Population(config)

# Add statistics computation for evolution logging
population.add_reporter(neat.StdOutReporter(show_species_detail=True))
stats = neat.StatisticsReporter()
population.add_reporter(stats)

# Run for a given number of generations
winner = population.run(eval_genomes, 100)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 35.56667 stdev: 15.89651
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 138
# Average adjusted fitness: 0.474
# Mean genetic distance 1.383, standard deviation 0.288
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150     75.0    0.474     0
# Total extinctions: 0
# Generation time: 0.500 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 39.72000 stdev: 14.56760
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 138
# Average adjusted fitness: 0.530
# Mean genetic distance 1.396, standard deviation 0.294
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150     75.0    0.530     1
# Total extinctions: 0
# Generation time: 0.340 sec (0.420 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 44.55333 stdev: 14.34505
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 138
# Average adjusted fitness: 0.559
# Mean genetic distance 1.315, standard deviation 0.310
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150     75.0    0.559     2
# Total extinctions: 0
# Generation time: 0.361 sec (0.400 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 46.66000 stdev: 15.95069
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 138
# Average adjusted fitness: 0.622
# Mean genetic distance 1.265, standard deviation 0.324
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   150     75.0    0.622     3
# Total extinctions: 0
# Generation time: 0.476 sec (0.419 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 45.73333 stdev: 15.80070
# Best fitness: 75.00000 - size: (3, 10) - species 1 - id 526
# Average adjusted fitness: 0.610
# Mean genetic distance 1.310, standard deviation 0.361
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   150     75.0    0.610     4
# Total extinctions: 0
# Generation time: 0.380 sec (0.412 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 48.36667 stdev: 16.45536
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.446
# Mean genetic distance 1.365, standard deviation 0.358
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   150     96.0    0.446     0
# Total extinctions: 0
# Generation time: 0.361 sec (0.403 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 50.64000 stdev: 18.33659
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.523
# Mean genetic distance 1.478, standard deviation 0.357
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   150     96.0    0.523     1
# Total extinctions: 0
# Generation time: 0.317 sec (0.391 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 55.36667 stdev: 17.48387
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.345
# Mean genetic distance 1.636, standard deviation 0.330
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   150     96.0    0.345     2
# Total extinctions: 0
# Generation time: 0.310 sec (0.381 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 53.75333 stdev: 17.05166
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.307
# Mean genetic distance 1.727, standard deviation 0.366
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   150     96.0    0.307     3
# Total extinctions: 0
# Generation time: 0.307 sec (0.372 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 54.42000 stdev: 18.50163
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.493
# Mean genetic distance 1.753, standard deviation 0.389
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   150     96.0    0.493     4
# Total extinctions: 0
# Generation time: 0.313 sec (0.367 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 54.95333 stdev: 18.17556
# Best fitness: 96.00000 - size: (4, 10) - species 1 - id 823
# Average adjusted fitness: 0.327
# Mean genetic distance 1.622, standard deviation 0.383
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   150     96.0    0.327     5
# Total extinctions: 0
# Generation time: 0.308 sec (0.347 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 50.44000 stdev: 18.11978
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.476
# Mean genetic distance 1.698, standard deviation 0.417
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   150    106.0    0.476     0
# Total extinctions: 0
# Generation time: 0.338 sec (0.347 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 52.53333 stdev: 18.20134
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.425
# Mean genetic distance 1.904, standard deviation 0.362
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   150    106.0    0.425     1
# Total extinctions: 0
# Generation time: 0.304 sec (0.341 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 51.66000 stdev: 18.19188
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.440
# Mean genetic distance 1.920, standard deviation 0.337
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   150    106.0    0.440     2
# Total extinctions: 0
# Generation time: 0.295 sec (0.323 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 52.00667 stdev: 18.62418
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.491
# Mean genetic distance 1.794, standard deviation 0.380
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   150    106.0    0.491     3
# Total extinctions: 0
# Generation time: 0.436 sec (0.329 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 50.96667 stdev: 18.71342
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.455
# Mean genetic distance 1.748, standard deviation 0.389
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   150    106.0    0.455     4
# Total extinctions: 0
# Generation time: 0.315 sec (0.324 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 55.37333 stdev: 19.02684
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.467
# Mean genetic distance 1.707, standard deviation 0.418
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   150    106.0    0.467     5
# Total extinctions: 0
# Generation time: 0.295 sec (0.322 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 54.01333 stdev: 18.82905
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.480
# Mean genetic distance 1.682, standard deviation 0.382
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   150    106.0    0.480     6
# Total extinctions: 0
# Generation time: 0.294 sec (0.321 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 55.00000 stdev: 18.77410
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.452
# Mean genetic distance 1.683, standard deviation 0.293
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   150    106.0    0.452     7
# Total extinctions: 0
# Generation time: 0.314 sec (0.321 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 55.62000 stdev: 18.37377
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.290
# Mean genetic distance 2.017, standard deviation 0.561
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   130    106.0    0.290     8
#      2    0    20       --       --     0
# Total extinctions: 0
# Generation time: 0.295 sec (0.320 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 55.68667 stdev: 18.57745
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.479
# Mean genetic distance 2.213, standard deviation 0.543
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   100    106.0    0.452     9
#      2    1    50     75.0    0.507     0
# Total extinctions: 0
# Generation time: 0.336 sec (0.322 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 57.72667 stdev: 18.49681
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.507
# Mean genetic distance 2.124, standard deviation 0.490
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    96    106.0    0.494    10
#      2    2    54     75.0    0.520     1
# Total extinctions: 0
# Generation time: 0.370 sec (0.325 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 58.58667 stdev: 18.24141
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.416
# Mean genetic distance 2.119, standard deviation 0.460
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    82    106.0    0.411    11
#      2    3    68     75.0    0.421     2
# Total extinctions: 0
# Generation time: 0.367 sec (0.332 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 55.15333 stdev: 18.23321
# Best fitness: 106.00000 - size: (4, 8) - species 1 - id 1648
# Average adjusted fitness: 0.412
# Mean genetic distance 2.264, standard deviation 0.606
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    64    106.0    0.374    12
#      2    4    68     75.0    0.451     3
#      3    0    18       --       --     0
# Total extinctions: 0
# Generation time: 0.329 sec (0.335 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 56.98000 stdev: 18.03680
# Best fitness: 106.00000 - size: (4, 8) - species 3 - id 1648
# Average adjusted fitness: 0.319
# Mean genetic distance 2.454, standard deviation 0.697
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    38    104.0    0.261    13
#      2    5    60     93.0    0.344     0
#      3    1    52    106.0    0.353     0
# Total extinctions: 0
# Generation time: 0.303 sec (0.322 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 60.32000 stdev: 18.43342
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.385
# Mean genetic distance 2.300, standard deviation 0.576
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    44    100.0    0.362    14
#      2    6    55    108.0    0.420     0
#      3    2    51    106.0    0.373     1
# Total extinctions: 0
# Generation time: 0.342 sec (0.325 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 57.44667 stdev: 20.22689
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.512
# Mean genetic distance 2.388, standard deviation 0.594
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    51    100.0    0.499    15
#      2    7    44    108.0    0.545     1
#      3    3    55    106.0    0.493     2
# Total extinctions: 0
# Generation time: 0.329 sec (0.328 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 58.74667 stdev: 19.35189
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.329
# Mean genetic distance 2.385, standard deviation 0.632
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    58    100.0    0.290    16
#      2    8    44    108.0    0.397     2
#      3    4    47    106.0    0.301     3
# Total extinctions: 0
# Generation time: 0.330 sec (0.331 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 60.09396 stdev: 19.12107
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.348
# Mean genetic distance 2.363, standard deviation 0.592
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    48    100.0    0.293    17
#      2    9    44    108.0    0.366     3
#      3    5    57    106.0    0.386     4
# Total extinctions: 0
# Generation time: 0.327 sec (0.333 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 57.95302 stdev: 20.79118
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.462
# Mean genetic distance 2.250, standard deviation 0.591
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    58    100.0    0.400    18
#      2   10    60    108.0    0.510     4
#      3    6    32    106.0    0.477     5
# Total extinctions: 0
# Generation time: 0.332 sec (0.336 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 62.58667 stdev: 19.24307
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.415
# Mean genetic distance 2.236, standard deviation 0.587
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    67     96.0    0.398    19
#      2   11    48    108.0    0.405     5
#      3    7    35    106.0    0.443     6
# Total extinctions: 0
# Generation time: 0.332 sec (0.336 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 62.47333 stdev: 19.76957
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
#
# Species 1 with 67 members is stagnated: removing it
# Average adjusted fitness: 0.373
# Mean genetic distance 2.013, standard deviation 0.764
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   12    86    108.0    0.413     6
#      3    8    64    106.0    0.333     7
# Total extinctions: 0
# Generation time: 0.311 sec (0.330 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 62.19333 stdev: 19.49109
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.372
# Mean genetic distance 2.045, standard deviation 0.763
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   13    88    108.0    0.436     7
#      3    9    62    106.0    0.308     8
# Total extinctions: 0
# Generation time: 0.328 sec (0.326 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 61.60667 stdev: 19.52875
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.474
# Mean genetic distance 2.101, standard deviation 0.717
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   14    90    108.0    0.535     8
#      3   10    60    106.0    0.413     9
# Total extinctions: 0
# Generation time: 0.312 sec (0.325 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 58.17333 stdev: 20.10663
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.529
# Mean genetic distance 2.119, standard deviation 0.702
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   15    89    108.0    0.555     9
#      3   11    61    106.0    0.503    10
# Total extinctions: 0
# Generation time: 0.289 sec (0.323 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 60.39333 stdev: 18.88276
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.346
# Mean genetic distance 2.084, standard deviation 0.681
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   16    86    108.0    0.354    10
#      3   12    64    106.0    0.338    11
# Total extinctions: 0
# Generation time: 0.282 sec (0.317 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 58.06667 stdev: 18.69213
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.315
# Mean genetic distance 2.126, standard deviation 0.693
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   17    83    108.0    0.321    11
#      3   13    67    106.0    0.309    12
# Total extinctions: 0
# Generation time: 0.303 sec (0.315 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 59.61333 stdev: 18.44443
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.338
# Mean genetic distance 2.272, standard deviation 0.707
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   18    88    108.0    0.329    12
#      3   14    62    106.0    0.348    13
# Total extinctions: 0
# Generation time: 0.309 sec (0.313 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 58.54000 stdev: 19.85838
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.372
# Mean genetic distance 2.201, standard deviation 0.705
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   19    83    108.0    0.382    13
#      3   15    67    106.0    0.363    14
# Total extinctions: 0
# Generation time: 0.305 sec (0.310 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 59.41333 stdev: 19.30740
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.333
# Mean genetic distance 2.221, standard deviation 0.728
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   20    79    108.0    0.348    14
#      3   16    71    106.0    0.318    15
# Total extinctions: 0
# Generation time: 0.268 sec (0.304 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 57.35333 stdev: 18.95121
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.303
# Mean genetic distance 2.259, standard deviation 0.776
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   21    79    108.0    0.356    15
#      3   17    71    106.0    0.251    16
# Total extinctions: 0
# Generation time: 0.331 sec (0.304 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 56.66667 stdev: 19.99422
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.504
# Mean genetic distance 2.381, standard deviation 0.776
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   22    77    108.0    0.542    16
#      3   18    73    106.0    0.466    17
# Total extinctions: 0
# Generation time: 0.284 sec (0.301 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 58.03333 stdev: 19.55042
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.397
# Mean genetic distance 2.313, standard deviation 0.805
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   23    80    108.0    0.435    17
#      3   19    70    106.0    0.359    18
# Total extinctions: 0
# Generation time: 0.287 sec (0.297 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 57.58667 stdev: 19.46490
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.305
# Mean genetic distance 2.531, standard deviation 0.821
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   24    85    108.0    0.378    18
#      3   20    61    106.0    0.231    19
#      4    0     4       --       --     0
# Total extinctions: 0
# Generation time: 0.338 sec (0.300 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 62.34000 stdev: 18.87002
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.310
# Mean genetic distance 2.468, standard deviation 0.798
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   25    68    108.0    0.412    19
#      3   21    47    106.0    0.336    20
#      4    1    35     66.0    0.182     0
# Total extinctions: 0
# Generation time: 0.265 sec (0.297 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 57.95333 stdev: 19.53197
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.303
# Mean genetic distance 2.638, standard deviation 0.732
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   26    59    108.0    0.366    20
#      3   22    49    106.0    0.275    21
#      4    2    37     75.0    0.267     0
#      5    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.274 sec (0.296 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 59.56000 stdev: 19.15706
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.352
# Mean genetic distance 2.592, standard deviation 0.648
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   27    43    108.0    0.379    21
#      3   23    40    106.0    0.323    22
#      4    3    36     75.0    0.272     1
#      5    1    32     75.0    0.433     0
# Total extinctions: 0
# Generation time: 0.304 sec (0.297 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 59.51656 stdev: 18.88545
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.421
# Mean genetic distance 2.496, standard deviation 0.683
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   28    37    108.0    0.456    22
#      3   24    37    106.0    0.421    23
#      4    4    36     75.0    0.396     2
#      5    2    40     75.0    0.410     1
# Total extinctions: 0
# Generation time: 0.305 sec (0.296 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 58.68667 stdev: 19.90515
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.458
# Mean genetic distance 2.446, standard deviation 0.616
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   29    38    108.0    0.528    23
#      3   25    35    106.0    0.407    24
#      4    5    47     75.0    0.454     3
#      5    3    30     75.0    0.444     2
# Total extinctions: 0
# Generation time: 0.333 sec (0.299 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 61.42000 stdev: 19.57082
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.362
# Mean genetic distance 2.472, standard deviation 0.616
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   30    38    108.0    0.397    24
#      3   26    35    106.0    0.319    25
#      4    6    45     80.0    0.356     0
#      5    4    33     75.0    0.377     3
# Total extinctions: 0
# Generation time: 0.309 sec (0.303 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 61.17881 stdev: 19.99870
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.564
# Mean genetic distance 2.504, standard deviation 0.628
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   31    41    108.0    0.644    25
#      3   27    33    106.0    0.530    26
#      4    7    40     80.0    0.517     1
#      5    5    37     75.0    0.564     4
# Total extinctions: 0
# Generation time: 0.350 sec (0.305 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 59.14570 stdev: 20.04842
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.327
# Mean genetic distance 2.475, standard deviation 0.585
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   32    38    108.0    0.383    26
#      3   28    34    106.0    0.270    27
#      4    8    47     89.0    0.348     0
#      5    6    30     75.0    0.309     5
# Total extinctions: 0
# Generation time: 0.350 sec (0.312 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 62.03356 stdev: 19.85600
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.364
# Mean genetic distance 2.475, standard deviation 0.582
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   33    38    108.0    0.398    27
#      3   29    35    106.0    0.328    28
#      4    9    51    105.0    0.412     0
#      5    7    25     75.0    0.318     6
# Total extinctions: 0
# Generation time: 0.358 sec (0.319 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 60.32215 stdev: 19.74715
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.434
# Mean genetic distance 2.533, standard deviation 0.641
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   34    40    108.0    0.484    28
#      3   30    32    106.0    0.367    29
#      4   10    44    105.0    0.465     1
#      5    8    34     75.0    0.417     7
# Total extinctions: 0
# Generation time: 0.329 sec (0.318 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 59.94667 stdev: 21.18987
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.546
# Mean genetic distance 2.551, standard deviation 0.643
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   35    38    108.0    0.559    29
#      3   31    32    106.0    0.496    30
#      4   11    45    105.0    0.596     2
#      5    9    34     75.0    0.536     8
# Total extinctions: 0
# Generation time: 0.331 sec (0.324 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 61.32215 stdev: 19.28844
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.352
# Mean genetic distance 2.494, standard deviation 0.661
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   36    40    108.0    0.358    30
#      3   32    29    106.0    0.278    31
#      4   12    42    105.0    0.454     3
#      5   10    39     75.0    0.317     9
# Total extinctions: 0
# Generation time: 0.372 sec (0.334 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 61.43333 stdev: 20.61987
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.564
# Mean genetic distance 2.486, standard deviation 0.733
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   37    40    108.0    0.615    31
#      3   33    33    106.0    0.564    32
#      4   13    39    105.0    0.583     4
#      5   11    38     75.0    0.494    10
# Total extinctions: 0
# Generation time: 0.400 sec (0.344 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 60.67333 stdev: 20.93211
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.488
# Mean genetic distance 2.519, standard deviation 0.745
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   38    38    108.0    0.526    32
#      3   34    32    107.0    0.426     0
#      4   14    42    105.0    0.538     5
#      5   12    38     75.0    0.463    11
# Total extinctions: 0
# Generation time: 0.288 sec (0.342 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 63.39333 stdev: 20.56693
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.405
# Mean genetic distance 2.520, standard deviation 0.776
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   39    39    108.0    0.458    33
#      3   35    34    107.0    0.403     1
#      4   15    40    105.0    0.408     6
#      5   13    37     75.0    0.352    12
# Total extinctions: 0
# Generation time: 0.278 sec (0.337 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 63.30667 stdev: 21.24302
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.385
# Mean genetic distance 2.511, standard deviation 0.762
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   40    41    108.0    0.479    34
#      3   36    33    107.0    0.307     2
#      4   16    40    106.0    0.407     0
#      5   14    35     75.0    0.346    13
# Total extinctions: 0
# Generation time: 0.290 sec (0.335 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 65.23490 stdev: 19.89651
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 3742
# Average adjusted fitness: 0.590
# Mean genetic distance 2.580, standard deviation 0.777
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   41    39    108.0    0.614    35
#      3   37    34    107.0    0.566     3
#      4   17    42    106.0    0.628     1
#      5   15    34     75.0    0.553    14
# Total extinctions: 0
# Generation time: 0.278 sec (0.327 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 62.54362 stdev: 21.18961
# Best fitness: 108.00000 - size: (5, 11) - species 4 - id 8931
# Average adjusted fitness: 0.374
# Mean genetic distance 2.548, standard deviation 0.779
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   42    38    108.0    0.363    36
#      3   38    37    107.0    0.393     4
#      4   18    44    108.0    0.443     0
#      5   16    31     75.0    0.297    15
# Total extinctions: 0
# Generation time: 0.297 sec (0.322 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 65.40667 stdev: 21.97122
# Best fitness: 108.00000 - size: (5, 11) - species 4 - id 8931
# Average adjusted fitness: 0.404
# Mean genetic distance 2.529, standard deviation 0.793
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   43    40    108.0    0.493    37
#      3   39    33    107.0    0.403     5
#      4   19    49    108.0    0.501     1
#      5   17    29     75.0    0.218    16
# Total extinctions: 0
# Generation time: 0.282 sec (0.315 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 65.66225 stdev: 20.44242
# Best fitness: 108.00000 - size: (5, 11) - species 4 - id 8931
# Average adjusted fitness: 0.421
# Mean genetic distance 2.512, standard deviation 0.723
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   44    40    108.0    0.423    38
#      3   40    37    107.0    0.379     6
#      4   20    46    108.0    0.481     2
#      5   18    28     79.0    0.402     0
# Total extinctions: 0
# Generation time: 0.336 sec (0.315 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 64.42384 stdev: 21.98959
# Best fitness: 108.00000 - size: (6, 11) - species 4 - id 9241
# Average adjusted fitness: 0.404
# Mean genetic distance 2.533, standard deviation 0.746
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   45    38    108.0    0.420    39
#      3   41    33    107.0    0.335     7
#      4   21    43    108.0    0.419     3
#      5   19    36    105.0    0.442     0
# Total extinctions: 0
# Generation time: 0.281 sec (0.310 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 63.18667 stdev: 22.55760
# Best fitness: 108.00000 - size: (6, 11) - species 4 - id 9241
# Average adjusted fitness: 0.381
# Mean genetic distance 2.453, standard deviation 0.751
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   46    37    108.0    0.421    40
#      3   42    25    107.0    0.291     8
#      4   22    42    108.0    0.441     4
#      5   20    46    105.0    0.370     1
# Total extinctions: 0
# Generation time: 0.289 sec (0.302 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 67.07333 stdev: 22.73708
# Best fitness: 108.00000 - size: (6, 11) - species 4 - id 9241
# Average adjusted fitness: 0.431
# Mean genetic distance 2.400, standard deviation 0.769
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   47    39    108.0    0.502    41
#      3   43    23    107.0    0.324     9
#      4   23    42    108.0    0.531     5
#      5   21    46    105.0    0.369     2
# Total extinctions: 0
# Generation time: 0.350 sec (0.297 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 63.94667 stdev: 21.42733
# Best fitness: 108.00000 - size: (6, 11) - species 4 - id 9241
# Average adjusted fitness: 0.384
# Mean genetic distance 2.407, standard deviation 0.777
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   48    38    108.0    0.372    42
#      3   44    24    106.0    0.295    10
#      4   24    43    108.0    0.462     6
#      5   22    46    107.0    0.408     0
# Total extinctions: 0
# Generation time: 0.280 sec (0.296 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 64.29801 stdev: 21.92757
# Best fitness: 108.00000 - size: (7, 11) - species 4 - id 9803
# Average adjusted fitness: 0.585
# Mean genetic distance 2.395, standard deviation 0.809
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   49    36    108.0    0.584    43
#      3   45    27    106.0    0.514    11
#      4   25    41    108.0    0.610     7
#      5   23    45    107.0    0.633     1
# Total extinctions: 0
# Generation time: 0.300 sec (0.298 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 67.06711 stdev: 21.05049
# Best fitness: 108.00000 - size: (5, 10) - species 4 - id 9374
# Average adjusted fitness: 0.430
# Mean genetic distance 2.389, standard deviation 0.735
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   50    36    108.0    0.406    44
#      3   46    27    106.0    0.343    12
#      4   26    46    108.0    0.538     8
#      5   24    41    107.0    0.433     2
# Total extinctions: 0
# Generation time: 0.286 sec (0.298 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 63.02667 stdev: 21.06623
# Best fitness: 108.00000 - size: (5, 10) - species 4 - id 9374
# Average adjusted fitness: 0.368
# Mean genetic distance 2.405, standard deviation 0.751
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   51    36    108.0    0.391    45
#      3   47    25    106.0    0.231    13
#      4   27    46    108.0    0.493     9
#      5   25    43    107.0    0.356     3
# Total extinctions: 0
# Generation time: 0.268 sec (0.297 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 65.98667 stdev: 19.43227
# Best fitness: 108.00000 - size: (5, 10) - species 4 - id 9374
# Average adjusted fitness: 0.409
# Mean genetic distance 2.387, standard deviation 0.744
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   52    32    108.0    0.385    46
#      3   48    29    106.0    0.301    14
#      4   28    40    108.0    0.502    10
#      5   26    49    107.0    0.445     4
# Total extinctions: 0
# Generation time: 0.270 sec (0.294 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 63.21333 stdev: 22.84282
# Best fitness: 108.00000 - size: (5, 10) - species 4 - id 9374
# Average adjusted fitness: 0.383
# Mean genetic distance 2.392, standard deviation 0.693
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   53    37    108.0    0.422    47
#      3   49    27    106.0    0.334    15
#      4   29    40    108.0    0.362    11
#      5   27    47    107.0    0.415     5
# Total extinctions: 0
# Generation time: 0.288 sec (0.295 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 68.88079 stdev: 22.27787
# Best fitness: 108.00000 - size: (5, 10) - species 4 - id 9374
# Average adjusted fitness: 0.495
# Mean genetic distance 2.436, standard deviation 0.733
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   54    36    108.0    0.500    48
#      3   50    34    106.0    0.458    16
#      4   30    36    108.0    0.508    12
#      5   28    45    107.0    0.513     6
# Total extinctions: 0
# Generation time: 0.288 sec (0.290 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 66.28477 stdev: 22.81959
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.582
# Mean genetic distance 2.414, standard deviation 0.735
# Population of 151 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   55    37    108.0    0.606    49
#      3   51    31    107.0    0.503    17
#      4   31    41    108.0    0.569    13
#      5   29    42    110.0    0.652     0
# Total extinctions: 0
# Generation time: 0.277 sec (0.290 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 64.21192 stdev: 23.09485
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.569
# Mean genetic distance 2.421, standard deviation 0.734
# Population of 150 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   56    39    108.0    0.621    50
#      3   52    33    107.0    0.439    18
#      4   32    36    108.0    0.612    14
#      5   30    42    110.0    0.601     1
# Total extinctions: 0
# Generation time: 0.297 sec (0.290 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 63.22000 stdev: 21.83724
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.472
# Mean genetic distance 2.451, standard deviation 0.695
# Population of 149 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   57    38    108.0    0.519    51
#      3   53    37    107.0    0.412    19
#      4   33    38    108.0    0.468    15
#      5   31    36    110.0    0.487     2
# Total extinctions: 0
# Generation time: 0.281 sec (0.283 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 65.14765 stdev: 22.20629
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
#
# Species 3 with 37 members is stagnated: removing it
# Average adjusted fitness: 0.525
# Mean genetic distance 2.424, standard deviation 0.676
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   58    50    108.0    0.543    52
#      4   34    41    108.0    0.525    16
#      5   32    59    110.0    0.508     3
# Total extinctions: 0
# Generation time: 0.271 sec (0.283 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 65.91333 stdev: 21.04121
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.539
# Mean genetic distance 2.510, standard deviation 0.696
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   59    46    108.0    0.527    53
#      4   35    60    108.0    0.533    17
#      5   33    43    110.0    0.558     4
# Total extinctions: 0
# Generation time: 0.285 sec (0.281 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 66.66443 stdev: 22.19820
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.415
# Mean genetic distance 2.592, standard deviation 0.631
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   60    47    108.0    0.383    54
#      4   36    73    108.0    0.482    18
#      5   34    30    110.0    0.382     5
# Total extinctions: 0
# Generation time: 0.273 sec (0.280 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 68.13333 stdev: 22.05649
# Best fitness: 110.00000 - size: (3, 8) - species 4 - id 10774
#
# Species 2 with 47 members is stagnated: removing it
# Average adjusted fitness: 0.482
# Mean genetic distance 2.449, standard deviation 0.531
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   37    72    110.0    0.493     0
#      5   35    78    108.0    0.470     6
# Total extinctions: 0
# Generation time: 0.290 sec (0.282 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 66.26667 stdev: 22.47270
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.590
# Mean genetic distance 2.353, standard deviation 0.472
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   38    65    108.0    0.648     1
#      5   36    85    110.0    0.532     7
# Total extinctions: 0
# Generation time: 0.312 sec (0.286 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 68.24000 stdev: 22.75952
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.565
# Mean genetic distance 2.257, standard deviation 0.522
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   39    58    108.0    0.599     2
#      5   37    92    110.0    0.531     8
# Total extinctions: 0
# Generation time: 0.315 sec (0.289 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 69.56667 stdev: 21.89838
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.464
# Mean genetic distance 2.280, standard deviation 0.496
# Population of 150 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   40    68    108.0    0.480     3
#      5   38    82    110.0    0.449     9
# Total extinctions: 0
# Generation time: 0.328 sec (0.293 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 69.20667 stdev: 23.13649
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.459
# Mean genetic distance 2.372, standard deviation 0.522
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   41    71    108.0    0.496     4
#      5   39    73    110.0    0.423    10
#      6    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.319 sec (0.297 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 69.26667 stdev: 21.60391
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.422
# Mean genetic distance 2.488, standard deviation 0.563
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   42    60    108.0    0.454     5
#      5   40    66    110.0    0.469    11
#      6    1    23    108.0    0.342     0
# Total extinctions: 0
# Generation time: 0.302 sec (0.297 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: 67.58389 stdev: 22.88081
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.430
# Mean genetic distance 2.464, standard deviation 0.471
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   43    41    108.0    0.453     6
#      5   41    42    110.0    0.426    12
#      6    2    66    108.0    0.409     1
# Total extinctions: 0
# Generation time: 0.283 sec (0.298 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 66.79195 stdev: 23.02589
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.520
# Mean genetic distance 2.299, standard deviation 0.513
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   44    42    108.0    0.488     7
#      5   42    32    110.0    0.521    13
#      6    3    76    108.0    0.551     2
# Total extinctions: 0
# Generation time: 0.298 sec (0.300 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 67.62000 stdev: 25.11591
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.618
# Mean genetic distance 2.148, standard deviation 0.547
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   45    40    108.0    0.629     8
#      5   43    39    110.0    0.620    14
#      6    4    70    108.0    0.605     3
# Total extinctions: 0
# Generation time: 0.302 sec (0.302 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 67.45638 stdev: 22.33981
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.435
# Mean genetic distance 2.119, standard deviation 0.535
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   46    44    108.0    0.406     9
#      5   44    46    110.0    0.476    15
#      6    5    59    108.0    0.424     4
# Total extinctions: 0
# Generation time: 0.301 sec (0.305 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 67.59732 stdev: 24.74132
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.508
# Mean genetic distance 2.174, standard deviation 0.568
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   47    49    108.0    0.529    10
#      5   45    47    110.0    0.490    16
#      6    6    53    108.0    0.503     5
# Total extinctions: 0
# Generation time: 0.292 sec (0.305 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 69.30872 stdev: 22.82760
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.457
# Mean genetic distance 2.163, standard deviation 0.580
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   48    51    108.0    0.460    11
#      5   46    50    110.0    0.446    17
#      6    7    49    108.0    0.465     6
# Total extinctions: 0
# Generation time: 0.316 sec (0.306 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 67.55333 stdev: 24.43237
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.611
# Mean genetic distance 2.210, standard deviation 0.569
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   49    51    108.0    0.600    12
#      5   47    54    110.0    0.572    18
#      6    8    45    108.0    0.661     7
# Total extinctions: 0
# Generation time: 0.313 sec (0.306 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 68.78000 stdev: 21.30379
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.452
# Mean genetic distance 2.165, standard deviation 0.552
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   50    48    108.0    0.463    13
#      5   48    54    110.0    0.418    19
#      6    9    49    108.0    0.475     8
# Total extinctions: 0
# Generation time: 0.295 sec (0.302 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 68.00662 stdev: 23.02619
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.440
# Mean genetic distance 2.169, standard deviation 0.559
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   51    52    108.0    0.468    14
#      5   49    53    110.0    0.456    20
#      6   10    46    108.0    0.395     9
# Total extinctions: 0
# Generation time: 0.367 sec (0.307 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 64.88742 stdev: 22.18541
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.591
# Mean genetic distance 2.194, standard deviation 0.559
# Population of 151 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   52    54    108.0    0.617    15
#      5   50    51    110.0    0.554    21
#      6   11    46    108.0    0.601    10
# Total extinctions: 0
# Generation time: 0.293 sec (0.306 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 66.70861 stdev: 21.13112
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.568
# Mean genetic distance 2.177, standard deviation 0.581
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   53    52    108.0    0.573    16
#      5   51    49    110.0    0.530    22
#      6   12    49    108.0    0.601    11
# Total extinctions: 0
# Generation time: 0.293 sec (0.307 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 64.56000 stdev: 23.47125
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.417
# Mean genetic distance 2.136, standard deviation 0.602
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   54    55    108.0    0.459    17
#      5   52    44    110.0    0.345    23
#      6   13    51    108.0    0.446    12
# Total extinctions: 0
# Generation time: 0.299 sec (0.307 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 67.14000 stdev: 22.27735
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.610
# Mean genetic distance 2.173, standard deviation 0.599
# Population of 150 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   55    53    108.0    0.603    18
#      5   53    48    110.0    0.589    24
#      6   14    49    108.0    0.636    13
# Total extinctions: 0
# Generation time: 0.303 sec (0.307 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 67.83333 stdev: 22.73306
# Best fitness: 110.00000 - size: (3, 8) - species 5 - id 10774
# Average adjusted fitness: 0.617
# Mean genetic distance 2.203, standard deviation 0.598
# Population of 149 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   56    54    108.0    0.611    19
#      5   54    44    110.0    0.591    25
#      6   15    51    108.0    0.649    14
# Total extinctions: 0
# Generation time: 0.307 sec (0.308 average)

# %%
# Show the best individual and its accuracy on test data
print(f"Best genome:\n{winner}")

winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
num_of_correct_predictions = 0
for input_example, correct_output in zip(test_x, test_y):
    output = winner_net.activate(input_example)
    prediction = np.argmax(output)
        
    if prediction == correct_output:
        num_of_correct_predictions += 1
    
print("\nTotal accuracy on the test data:", num_of_correct_predictions / len(test_y))

# Render the best network
node_names = {-1:"x1", -2: "x2", -3: "x3", -4: "x4", 0:"setosa", 1:"virginica", 2:"versicolor"}
visualize.draw_net(
    config,
    genome=winner,
    node_names=node_names,
    show_disabled=True,
    prune_unused=False
) 

# Plot the statistics
visualize.plot_stats(stats, ylog=False, view=True)
visualize.plot_species(stats, view=True)
# Out:
# Best genome:
# Key: 10774
# Fitness: 110.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=1.5689831864967803, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.5483639192589179, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-2.5689471922222205, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-4, 0), weight=-2.2261474407391226, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-2.3589568606765523, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-5.243226860891509, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=-0.9054841274457035, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=1.8499231118485358, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=5.07857905404137, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-2.08186193966593, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=1.3131133191822895, enabled=True)
#
# Total accuracy on the test data: 0.9736842105263158

# %% [markdown]
# ## Domácí úkol - Zpětnovazební učení s využitím neuroevoluce
#
# Za domácí úkol budete mít vyzkoušet si vyřešit některá prostředí z knihovny [Gymnasium](https://gymnasium.farama.org/). Vyzkoušet můžete buď NEAT (v takovém případě můžete použít třeba knihovnu, kterou jsme si právě vyzkoušeli, jen nezapomeňte přizpůsobit konfigurační soubor, fitness a tak podobně), vyvíjet jen vektor vah fixní sítě, nebo cokoli vás napadne.
#
# [Detailní zadání](https://kam.mff.cuni.cz/~lorenc/teach/23-24/PIA/homeworks-neuroevolution.html) je možno najít na stránkách cvičení.
